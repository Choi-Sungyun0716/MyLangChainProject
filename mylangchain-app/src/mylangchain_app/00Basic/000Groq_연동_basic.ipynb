# %%
print("Hello LangChain")
# Out:
# Hello LangChain

# %%
import os
from dotenv import load_dotenv
from langchain_core.prompts import ChatPromptTemplate
from langchain_openai import ChatOpenAI 

load_dotenv(dotenv_path='.env')
OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")
print(OPENAI_API_KEY[:10])
# Out:
# gsk_1EJvXFjSXAs

# %%
# prompt + llm + output 

# prompt
prompt = ChatPromptTemplate.from_messages(
    [ ("system", "당신은 개발자입니다.") , 
     ("user", "{input}") ]
)
print(type(prompt))
print(prompt)
# Out:
# <class 'langchain_core.prompts.chat.ChatPromptTemplate'>
# input_variables=['input'] input_types={} partial_variables={} messages=[SystemMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='당신은 개발자입니다.'), additional_kwargs={}), HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['input'], input_types={}, partial_variables={}, template='{input}'), additional_kwargs={})]

# %%
prompt_text = prompt.format(input="파이썬은 무엇인가요? 자세하게 설명해주세요")
print(type(prompt_text))
print(prompt_text)
# Out:
# <class 'str'>
# System: 당신은 개발자입니다.
# Human: 파이썬은 무엇인가요? 자세하게 설명해주세요

# %%
#llm = ChatOpenAI(api_key=OPENAI_API_KEY, model_name="gpt-3.5-turbo-0125")

# Groq API를 사용하는 ChatOpenAI 인스턴스 생성
llm = ChatOpenAI(
    #api_key=OPENAI_API_KEY,
    base_url="https://api.groq.com/openai/v1",  # Groq API 엔드포인트
    #model="meta-llama/llama-4-scout-17b-16e-instruct",
    #model="moonshotai/kimi-k2-instruct-0905",
    model="openai/gpt-oss-120b",
    temperature=0.7
)
print(type(llm))
print(llm)
# Out:
# <class 'langchain_openai.chat_models.base.ChatOpenAI'>
# client=<openai.resources.chat.completions.completions.Completions object at 0x0000025411432210> async_client=<openai.resources.chat.completions.completions.AsyncCompletions object at 0x0000025411432F00> root_client=<openai.OpenAI object at 0x0000025411431820> root_async_client=<openai.AsyncOpenAI object at 0x0000025411432750> model_name='openai/gpt-oss-120b' temperature=0.7 model_kwargs={} openai_api_key=SecretStr('**********') openai_api_base='https://api.groq.com/openai/v1'

# %%
try:
    response = llm.invoke(prompt_text)
    print(type(response))
    print("응답:", response.content)
except Exception as e:
    print(f"오류 발생: {e}")
# Out:
# <class 'langchain_core.messages.ai.AIMessage'>
# 응답: **Python(파이썬)**은 1991년 네덜란드의 프로그래머 **귀도 반 로섬(Guido van Rossum)**이 처음 발표한 고수준(high‑level), 인터프리터형(interpreted) 프로그래밍 언어입니다. 현재는 전 세계에서 가장 널리 사용되는 언어 중 하나이며, **웹 개발, 데이터 과학, 인공지능, 자동화, 임베디드 시스템, 교육** 등 다양한 분야에서 활용됩니다. 아래에서는 파이썬의 주요 특징, 역사, 설계 철학, 핵심 구성 요소, 사용 사례, 그리고 배우기 위한 기본적인 로드맵을 자세히 살펴보겠습니다.
#
# ---
#
# ## 1. 파이썬의 핵심 특징
#
# | 특징 | 설명 | 장점 |
# |------|------|------|
# | **읽기 쉬운 문법** | 들여쓰기(Indentation)로 블록을 구분하고, 불필요한 기호(세미콜론, 중괄호 등)를 최소화 | 코드 가독성·유지보수성 향상 |
# | **동적 타이핑(Dynamic Typing)** | 변수 선언 시 타입을 명시하지 않음; 실행 시점에 타입이 결정 | 빠른 프로토타이핑·유연성 |
# | **인터프리터 언어** | 소스 코드를 바로 실행 (컴파일 단계가 없음) | 개발·디버깅 속도 빠름 |
# | **풍부한 표준 라이브러리** | “배터리 포함(Batteries Included)” 철학에 따라 파일 I/O, 네트워크, 웹, 데이터베이스, 멀티쓰레딩 등 다양한 모듈 제공 | 외부 패키지 없이도 많은 작업 수행 가능 |
# | **멀티 패러다임 지원** | 절차형, 객체지향(OOP), 함수형 프로그래밍 지원 | 문제에 맞는 스타일 선택 가능 |
# | **플랫폼 독립성** | Windows, macOS, Linux, iOS, Android 등 거의 모든 운영체제에서 실행 | 배포·운영이 용이 |
# | **확장성** | C/C++ 로 작성된 모듈을 쉽게 연동 (CPython), Jython, IronPython 등 다양한 구현체 존재 | 성능이 중요한 부분을 네이티브 코드로 보강 가능 |
# | **활발한 커뮤니티** | PyPI(Python Package Index) 300,000+ 패키지, 수많은 튜토리얼·문서·포럼 | 문제 해결·학습 자료가 풍부 |
#
# ---
#
# ## 2. 파이썬의 역사와 버전 흐름
#
# | 연도 | 주요 사건 |
# |------|-----------|
# | **1989** | 귀도 반 로섬이 “ABC” 언어의 개선판을 구상 |
# | **1991** | 첫 번째 공개 버전 **Python 0.9.0** 발표 (예외 처리, 함수, 모듈) |
# | **1994** | **Python 1.0** 출시 – 기본 데이터 구조(list, dict 등)와 모듈 시스템 도입 |
# | **2000** | **Python 2.0** 출시 – 리스트 컴프리헨션, 가비지 컬렉션, 유니코드 지원 |
# | **2008** | **Python 3.0** (Python 3000) 발표 – 언어 자체의 깨끗한 정리 (print → print()) 등 호환성 파괴적인 변경 |
# | **2014** | **Python 3.4** – `asyncio` (비동기 I/O) 도입 |
# | **2018** | **Python 3.7** – 데이터 클래스(`@dataclass`), 개선된 `async`/`await` |
# | **2020** | **Python 3.9** – 딕셔너리 병합 연산자(`|`), 타입 힌트 개선 |
# | **2021** | **Python 3.10** – 패턴 매칭(`match`/`case`) 도입 |
# | **2023** | **Python 3.12** – 성능 향상(파이썬 인터프리터 최적화), 새로운 파서 등 |
# | **2025 (예정)** | **Python 3.13** – 지속적인 성능 개선과 표준 라이브러리 정비 예정 |
#
# > **참고**: 현재(2025년) 가장 널리 사용되는 버전은 Python 3.11/3.12이며, Python 2.x는 2020년 1월에 공식 지원이 종료되었습니다.
#
# ---
#
# ## 3. 파이썬 설계 철학 – “The Zen of Python”
#
# 파이썬은 **PEP 20**에 정의된 *Zen of Python*이라는 설계 원칙을 따릅니다. `import this` 명령어를 입력하면 확인할 수 있습니다.
#
# ```
# Beautiful is better than ugly.
# Explicit is better than implicit.
# Simple is better than complex.
# Complex is better than complicated.
# ... (생략)
# ```
#
# 이 원칙들은 **가독성, 명시성, 단순성**을 중시하는 파이썬 코딩 스타일을 형성합니다.
#
# ---
#
# ## 4. 파이썬의 핵심 구성 요소
#
# ### 4.1. 기본 데이터 타입
#
# | 타입 | 설명 | 예시 |
# |------|------|------|
# | `int` | 정수 | `42` |
# | `float` | 부동소수점 | `3.14` |
# | `bool` | 불리언 | `True`, `False` |
# | `str` | 문자열 (유니코드) | `"Hello"` |
# | `list` | 가변 배열 | `[1, 2, 3]` |
# | `tuple` | 불변 배열 | `(1, 2, 3)` |
# | `dict` | 키‑값 매핑 | `{'name': 'Alice', 'age': 30}` |
# | `set` | 중복 없는 집합 | `{1, 2, 3}` |
# | `bytes` | 바이너리 데이터 | `b'abc'` |
#
# ### 4.2. 제어 흐름
#
# ```python
# # 조건문
# if x > 0:
#     print("양수")
# elif x == 0:
#     print("영")
# else:
#     print("음수")
#
# # 반복문
# for i in range(5):
#     print(i)   # 0~4 출력
#
# while some_condition:
#     # 반복 로직
#     pass
# ```
#
# ### 4.3. 함수와 람다
#
# ```python
# def greet(name: str = "World") -> str:
#     """인사를 반환하는 함수"""
#     return f"Hello, {name}!"
#
# # 람다(익명 함수)
# square = lambda x: x * x
# ```
#
# ### 4.4. 객체지향 프로그래밍(OOP)
#
# ```python
# class Animal:
#     def __init__(self, name):
#         self.name = name
#
#     def speak(self):
#         raise NotImplementedError
#
# class Dog(Animal):
#     def speak(self):
#         return "멍멍"
#
# class Cat(Animal):
#     def speak(self):
#         return "야옹"
#
# dog = Dog("바둑이")
# print(dog.speak())   # 멍멍
# ```
#
# ### 4.5. 모듈과 패키지
#
# - **모듈**: `.py` 파일 하나가 하나의 모듈이 됩니다. `import math`와 같이 사용.
# - **패키지**: 디렉터리 구조와 `__init__.py` 파일을 이용해 모듈을 그룹화.
#
# ```python
# # mypkg/__init__.py
# from .utils import helper
#
# # mypkg/utils.py
# def helper():
#     print("헬퍼 함수")
# ```
#
# ```python
# from mypkg import helper
# helper()
# ```
#
# ### 4.6. 표준 라이브러리 주요 모듈
#
# | 카테고리 | 모듈 | 주요 기능 |
# |----------|------|-----------|
# | 파일·IO | `os`, `pathlib`, `shutil` | 파일 시스템 작업 |
# | 네트워크 | `socket`, `http.client`, `urllib` | 저수준·고수준 네트워크 |
# | 웹 | `http.server`, `cgi` | 간단한 웹 서버 |
# | 데이터베이스 | `sqlite3`, `sqlite3` | 내장 DB |
# | 멀티쓰레딩·멀티프로세싱 | `threading`, `multiprocessing`, `asyncio` | 동시성 |
# | 날짜·시간 | `datetime`, `time`, `calendar` | 날짜·시간 처리 |
# | 암호화·해시 | `hashlib`, `hmac`, `secrets` | 보안 관련 |
# | 테스트 | `unittest`, `doctest` | 테스트 프레임워크 |
# | 로그 | `logging` | 로깅 시스템 |
# | 정규표현식 | `re` | 문자열 패턴 매칭 |
#
# ---
#
# ## 5. 파이썬 실행 환경
#
# | 환경 | 설명 | 장점 |
# |------|------|------|
# | **CPython** | 가장 널리 쓰이는 기본 구현 (C 언어로 작성) | 호환성 최상, 풍부한 C 확장 |
# | **PyPy** | JIT(Just‑In‑Time) 컴파일러 기반, 빠른 실행 속도 | CPU‑bound 작업에서 성능 향상 |
# | **Jython** | Java 플랫폼 위에서 동작, Java 클래스와 직접 연동 | Java 생태계와 통합 |
# | **IronPython** | .NET 플랫폼용 구현 | .NET 라이브러리 활용 |
# | **MicroPython** | 마이크로컨트롤러(ESP32, STM32 등)용 경량 구현 | 임베디드 시스템에 적합 |
# | **Anaconda** | 과학·데이터 분석용 배포판 (패키지 관리 conda 포함) | 패키지 의존성 관리 용이 |
# | **Docker / VS Code / PyCharm** | 개발·배포용 툴 | 환경 격리·IDE 지원 |
#
# ---
#
# ## 6. 파이썬 활용 분야와 대표 라이브러리
#
# | 분야 | 주요 라이브러리·프레임워크 | 설명 |
# |------|--------------------------|------|
# | **웹 개발** | Django, Flask, FastAPI, Bottle | 풀스택·마이크로 서비스 구축 |
# | **데이터 과학** | NumPy, pandas, SciPy, matplotlib, seaborn | 수치 연산·데이터 전처리·시각화 |
# | **머신러닝·AI** | scikit-learn, TensorFlow, PyTorch, Keras, XGBoost | 모델링·딥러닝·강화학습 |
# | **자동화·스크립팅** | Selenium, PyAutoGUI, requests, BeautifulSoup | 웹 스크래핑·테스트 자동화·시스템 관리 |
# | **네트워크·보안** | paramiko, scapy, cryptography, nmap | SSH 자동화·패킷 조작·암호화 |
# | **게임 개발** | Pygame, Panda3D | 2D·3D 게임 프로토타입 |
# | **임베디드** | MicroPython, CircuitPython | 마이크로컨트롤러 프로그래밍 |
# | **과학·공학** | SymPy, BioPython, Astropy | 기호 연산·생물정보·천문학 |
# | **데스크톱 GUI** | Tkinter, PyQt, Kivy, wxPython | 크로스플랫폼 GUI 애플리케이션 |
# | **클라우드·서버리스** | AWS Lambda (Python runtime), Google Cloud Functions | 서버리스 함수 작성 |
#
# ---
#
# ## 7. 파이썬 배우는 로드맵 (초급 → 고급)
#
# 1. **기초 문법**
#    - 변수, 자료형, 연산자, 제어문, 함수, 파일 입출력
#    - 온라인 튜토리얼: *Python 공식 튜토리얼*, *Codecademy*, *점프 투 파이썬* 등
#
# 2. **데이터 구조와 알고리즘**
#    - 리스트, 튜플, 딕셔너리, 집합 활용
#    - 기본 알고리즘(정렬, 탐색) 구현 연습
#
# 3. **객체지향 프로그래밍**
#    - 클래스, 상속, 다형성, 특수 메서드(`__init__`, `__repr__` 등)
#
# 4. **표준 라이브러리 활용**
#    - `os`, `sys`, `datetime`, `json`, `logging` 등 실무에 자주 쓰이는 모듈 익히기
#
# 5. **가상 환경 & 패키지 관리**
#    - `venv`, `virtualenv`, `conda` 사용법
#    - `pip`, `pipenv`, `poetry`로 패키지 설치·관리
#
# 6. **버전 관리와 테스트**
#    - `git` 기본 흐름, `unittest`/`pytest` 테스트 작성
#    - CI/CD(예: GitHub Actions) 기본 설정
#
# 7. **전문 분야 선택**
#    - **웹** → Flask/Django 기본 프로젝트 구축 → REST API, ORM, 인증 구현
#    - **데이터** → NumPy/pandas 데이터 전처리 → 시각화 → 간단한 머신러닝 모델 (scikit-learn)
#    - **AI** → PyTorch/TensorFlow 튜토리얼 → CNN, RNN, 트랜스포머 실습
#    - **자동화** → Selenium/Requests 로 웹 스크래핑 → 스케줄러(APScheduler)
#
# 8. **고급 주제**
#    - 비동기 프로그래밍 (`asyncio`, `aiohttp`)
#    - C 확장 모듈 (`Cython`, `ctypes`)
#    - 메모리 프로파일링(`tracemalloc`, `memory_profiler`)
#    - 성능 최적화 (PyPy, JIT, 멀티프로세싱)
#
# 9. **프로젝트와 포트폴리오**
#    - 오픈소스 기여(예: GitHub 이슈 해결)
#    - 개인 프로젝트(웹 서비스, 데이터 분석 보고서, 챗봇 등)
#
# 10. **커뮤니티와 최신 트렌드**
#     - PyCon, 한국 파이썬 컨퍼런스(PyCon KR) 참여
#     - 최신 PEP(예: 패턴 매칭, 타입 힌트 개선) 읽고 실무에 적용
#
# ---
#
# ## 8. 파이썬 코드 예시: 간단한 웹 서버와 API
#
# 아래는 **FastAPI**를 이용해 “Hello, World!”와 현재 시각을 반환하는 간단한 REST API를 만드는 예시입니다.
#
# ```python
# # app.py
# from fastapi import FastAPI
# from datetime import datetime
#
# app = FastAPI()
#
# @app.get("/")
# def read_root():
#     return {"message": "Hello, World!"}
#
# @app.get("/time")
# def get_time():
#     return {"now": datetime.utcnow().isoformat() + "Z"}
# ```
#
# 실행 방법:
#
# ```bash
# # 가상 환경 생성 및 활성화
# python -m venv venv
# source venv/bin/activate   # Windows: venv\Scripts\activate
#
# # FastAPI와 Uvicorn 설치
# pip install fastapi uvicorn
#
# # 서버 실행
# uvicorn app:app --reload
# ```
#
# 브라우저에서 `http://127.0.0.1:8000/`와 `http://127.0.0.1:8000/time`에 접속하면 JSON 응답을 확인할 수 있습니다. 또한 `http://127.0.0.1:8000/docs`에서 자동 생성된 Swagger UI 문서를 이용해 API를 테스트할 수 있습니다.
#
# ---
#
# ## 9. 파이썬 학습에 도움이 되는 자료
#
# | 유형 | 추천 자료 |
# |------|-----------|
# | **책** | *점프 투 파이썬* (박응용), *Fluent Python* (Luciano Ramalho), *Python Crash Course* (Eric Matthes) |
# | **온라인 코스** | Coursera “Python for Everybody”, Udemy “Complete Python Bootcamp”, edX “Introduction to Computer Science using Python” |
# | **문서** | 공식 문서 <https://docs.python.org/3/> (특히 튜토리얼, 라이브러리 레퍼런스) |
# | **문제 풀이** | LeetCode, HackerRank, Codewars – 파이썬 태그 활용 |
# | **커뮤니티** | Stack Overflow, Reddit r/learnpython, 한국 파이썬 사용자 모임(PythonKR) |
# | **블로그·튜토리얼** | Real Python, Towards Data Science, 파이썬 코딩 도장 등 |
#
# ---
#
# ## 10. 마무리 – 왜 파이썬을 배워야 할까?
#
# 1. **생산성**: 짧은 코드와 풍부한 라이브러리 덕분에 아이디어를 빠르게 구현할 수 있습니다.
# 2. **다양한 직무**: 웹 개발자, 데이터 과학자, AI 엔지니어, 자동화 엔지니어 등 여러 직무에서 기본 언어로 활용됩니다.
# 3. **커리어 성장**: 기업들이 파이썬 개발자를 지속적으로 채용하고 있으며, 연봉 수준도 높은 편입니다.
# 4. **학습 난이도**: 문법이 직관적이어서 프로그래밍 입문자에게 최적의 첫 번째 언어가 됩니다.
#
# 파이썬은 **“읽기 쉽고, 쓰기 쉬우며, 확장하기 쉬운”** 언어라는 목표를 충실히 이행하고 있습니다. 위에서 소개한 개념들을 차근차근 익히고, 실제 프로젝트에 적용해 보면서 경험을 쌓는다면 어느새 파이썬 전문가가 되어 있을 것입니다. 🚀
#
# 궁금한 점이 있으면 언제든 물어보세요!

# %% [markdown]
# # LCEL

# %%
from langchain_core.output_parsers import StrOutputParser

output_parser = StrOutputParser()

# %%
chain = prompt | llm | output_parser
print(type(chain))
print(chain)
# Out:
# <class 'langchain_core.runnables.base.RunnableSequence'>
# first=ChatPromptTemplate(input_variables=['input'], input_types={}, partial_variables={}, messages=[SystemMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='당신은 개발자입니다.'), additional_kwargs={}), HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['input'], input_types={}, partial_variables={}, template='{input}'), additional_kwargs={})]) middle=[ChatOpenAI(client=<openai.resources.chat.completions.completions.Completions object at 0x0000025411432210>, async_client=<openai.resources.chat.completions.completions.AsyncCompletions object at 0x0000025411432F00>, root_client=<openai.OpenAI object at 0x0000025411431820>, root_async_client=<openai.AsyncOpenAI object at 0x0000025411432750>, model_name='openai/gpt-oss-120b', temperature=0.7, model_kwargs={}, openai_api_key=SecretStr('**********'), openai_api_base='https://api.groq.com/openai/v1')] last=StrOutputParser()

# %%
response = chain.invoke({"input":"지구의 자전주기는 얼마인가요?"})

# %%
print(type(response))
print(response)
# Out:
# <class 'str'>
# 지구는 자전축을 중심으로 하루에 한 번 회전합니다.
#
# - **천문학적으로 정의되는 ‘항성일(sidereal day)’**
#   - 약 **23시간 56분 4초** (≈ 86 400 초)
#   - 별을 기준으로 보았을 때 지구가 한 바퀴 도는 시간입니다.
#
# - **일상 생활에서 사용하는 ‘태양일(solar day)’**
#   - 약 **24시간** (정확히는 24시간 0분 0초)
#   - 태양이 하늘에서 같은 위치에 다시 오기까지 걸리는 시간이며, 우리 시계가 맞추는 기준입니다.
#
# 즉, 지구의 자전주기는 **23시간 56분 정도**(항성일)이며, 일상적인 시간 단위인 **24시간**에 가깝게 맞춰져 있습니다.
